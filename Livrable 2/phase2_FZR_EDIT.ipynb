# %% [markdown]
# ![machine-learning-et-big-data.jpg](data:image/jpeg;base64,...)
# # Livrable 2
#
# ## Débruitage

# %% [markdown]
# ### Groupe de projet 1 :
# - Rémi Papin
# - Fabien Richard
# - Zacharia Azzouzi
# <br>
# <br>
#
# ### Introduction
#
# A la suite de notre premier livrable de classification binaire, ce second livrable se concentre sur la réalisation d'une phase de prétraitement de l'image de nos différents jeux de données.
#
# Dans un premier temps, ce livrable présente une méthode pour générer un dataset d'images bruitées puis l'implémentation d'un autoencodeur capable de regénérer des images de bonnes qualitées. Dans ce cas, les labels sont les images elles-mêmes.

# %% [markdown]
# ## Import
#
# L'ensemble des imports des bibliothèques pour mener à bien ce projet.

# %%
import os
import random
import datetime
import pathlib
import configuration
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from tensorboard.plugins.hparams import api as hp
from skimage.util import random_noise
# %matplotlib inline

data_dir = configuration.data_dir

# %% [markdown]
# ## Datasets
#
# Le script qui suit utilise toutes les images du dataset original pour générer un dataset équivalent d'image bruitée.

# %%
generate_dataset_noise=False
if(generate_dataset_noise):
    for file in os.listdir(data_dir+"/clean"):
        # Load the image
        image = cv2.imread(os.path.join(data_dir+"/clean",file))
        if image is not None:
            # Add salt-and-pepper noise to the image
            noise = random_noise(image, mode='s&p', amount=0.03+(random.random()*0.5))

            # The above function returns a floating-point image in the range [0, 1]
            # so need to change it to 'uint8' with range [0,255]
            noise = np.array(255 * noise, dtype=np.uint8)
            cv2.imwrite(os.path.join(data_dir+"/noise",file),noise)
    #break #Uncomment to test the noisification on the first image only

# %% [markdown]
# Le script qui suit charge le dataset tout en appliquant une pipeline dessus pour unifier le format des données. Le pipeline consiste à redimensionner les images selon les variables ``ìmage_h`` et ``image_w`` et à passer les valeurs, qui sont originelement entre 0 et 255, entre 0 et 1.
# Nous chargeons seulement 200 éléments dans le dataset pour permettre une execution rapide et moins coûteuse en ressources.

# %%
image_h = 304
image_w = 304
batch_s = 8

validation_threshold=0.2

valid_images = [".jpg",".gif",".png"]

clean_set = []
noisy_set = []

clean_files=os.listdir(data_dir+"/clean")
random.shuffle(clean_files)
# we are loading only 200 image to speed up the process
for file in clean_files[:200]:
    ext = os.path.splitext(file)[1]
    if ext.lower() not in valid_images or not os.path.isfile(os.path.join(data_dir+"/noise",file)) :
        continue
    clean_img=cv2.imread(os.path.join(data_dir+"/clean",file))
    clean_img=cv2.resize(clean_img, (image_h, image_w))
    clean_img=clean_img.astype('float32') / 255.
    
    noisy_img=cv2.imread(os.path.join(data_dir+"/noise",file))
    noisy_img=cv2.resize(noisy_img, (image_h, image_w))
    noisy_img=noisy_img.astype('float32') / 255.
    clean_set.append(clean_img)
    noisy_set.append(noisy_img)
clean_set = np.array(clean_set, dtype=object)
noisy_set = np.array(noisy_set, dtype=object)

split_index=int(noisy_set.shape[0]*(1-validation_threshold))

(clean_train_set, clean_test_set)=np.split(clean_set, [split_index])
(noisy_train_set, noisy_test_set)=np.split(noisy_set, [split_index])

print("Found {:d} clean files, {:d} train / {:d} test".format(clean_set.shape[0], clean_train_set.shape[0], clean_test_set.shape[0]))
print("Found {:d} noisy files, {:d} train / {:d} test".format(noisy_set.shape[0], noisy_train_set.shape[0], noisy_test_set.shape[0]))
# Out:
# Found 200 clean files, 160 train / 40 test
# Found 200 noisy files, 160 train / 40 test

# %% [markdown]
# ## Affichage

# %%
def display_image(X, n):
    plt.figure(figsize=(10, 10))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        plt.imshow(X[i].astype('float32'))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

display_image(clean_train_set, n=4)
display_image(noisy_train_set, n=4)

# %% [markdown]
# On peut observer les images originales sur la première ligne et les images bruitées correspondantes en dessous. Pour l'entrainement, les labels sont les images elles-mêmes.

# %% [markdown]
# ## Construction du modèle
# Pour réaliser ce modèle nous avons créé une architecture reposant sur plusieurs couches :
#
# - Une layers Input
# - Plusieurs couches en fonction du paramètre ``filters`` (encodeur) :
#     - Une layers Conv2D
#     - Une layers MaxPooling2D
# - Plusieurs couches en fonction du paramètre ``filters`` (décodeur) :
#     - Une layers Conv2D
#     - Une layers UpSampling2D
# - Une layers Conv2D

# %%
def build_autoencoder(height, width, depth, filters=(32, 64)):
    # initialize the input shape to be "channels last" along with
    # the channels dimension itself
    # channels dimension itself
    inputShape = (height, width, depth)
    chanDim = -1
    # define the input to the encoder
    inputs = layers.Input(shape=inputShape)
    x = inputs
    # loop over the number of filters
    for f in filters:
        # apply a CONV => MAX_POOLING
        x = layers.Conv2D(f, (3, 3), activation='relu', padding="same")(x)
        x = layers.MaxPooling2D((2, 2), padding='same')(x)
        
    # loop over our number of filters again, but this time in
    # reverse order
    for f in filters[::-1]:
        # apply a CONV => UP_SAMPLING
        x = layers.Conv2D(f, (3, 3), activation='relu', padding='same')(x)
        x = layers.UpSampling2D((2, 2))(x)
    # apply a single CONV_TRANSPOSE layer used to recover the
    # original depth of the image
    x = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
    # our autoencoder is the encoder + decoder
    autoencoder = keras.models.Model(inputs, x,
        name="autoencoder")
    # return a 2-tuple of the input and autoencoder
    return (inputs, autoencoder)


(encoder_inputs, autoencoder) = build_autoencoder(image_h, image_w, 3, filters=(16, 32))

# Model summary
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 304, 304, 3)]     0
#
#  conv2d (Conv2D)             (None, 304, 304, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 152, 152, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 152, 152, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 76, 76, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 76, 76, 32)        9248
#
#  up_sampling2d (UpSampling2D  (None, 152, 152, 32)     0
#  )
#
#  conv2d_3 (Conv2D)           (None, 152, 152, 16)      4624
#
#  up_sampling2d_1 (UpSampling  (None, 304, 304, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 304, 304, 3)       435
#
# =================================================================
# Total params: 19,395
# Trainable params: 19,395
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Checkpoint
#
# Pour ne pas perdre du temps à ré entrainer les modèles à chaque fois nous réalisons des checkpoints nous permettant de conserver les valeurs de notre modèle le plus performant.

# %%
# Prepare for model checkpoints
checkpoint_path = "training/cp_autoencoder_{epoch:02d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1,
                                                 mode='min')

log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, histogram_freq=1)
hparams_callback = hp.KerasCallback(log_dir, {
    'num_relu_units': 16,
    'dropout': 0.2
})

# %% [markdown]
# ### Entrainement du modèle
#
# Nous compilons notre modèle avec l'optimiseur ``adam`` et nous récupérons la loss à l'aide de la ``binary_crossentropy``.

# %%
# Compile the model
autoencoder.compile(optimizer="adam",loss= 'binary_crossentropy')

# %%
epochs=100

# Run the model
history = autoencoder.fit(tf.convert_to_tensor(noisy_train_set, dtype=tf.float32), tf.convert_to_tensor(clean_train_set, dtype=tf.float32),
                          epochs=epochs, batch_size=batch_s,
                          shuffle=True,
                          validation_data=(tf.convert_to_tensor(noisy_test_set, dtype=tf.float32), tf.convert_to_tensor(clean_test_set, dtype=tf.float32)),
                          callbacks=[cp_callback,tensorboard_callback])
 

# Save the model
save_path = "checkpoints/autoencoder.h5"
autoencoder.save_weights(save_path)

# Display training and validation loss Visualisation des pertes d'apprentissage (Train) et de validation (Test)
plt.plot( history.history['loss'],
         label='train')
plt.plot( history.history['val_loss'],
         label='test')
plt.legend()
# Out:
# Epoch 1/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6825
# Epoch 00001: val_loss improved from inf to 0.63971, saving model to training/cp_autoencoder_01.ckpt
# 20/20 [==============================] - 5s 49ms/step - loss: 0.6811 - val_loss: 0.6397
# Epoch 2/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.6116
# Epoch 00002: val_loss improved from 0.63971 to 0.54634, saving model to training/cp_autoencoder_02.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.6101 - val_loss: 0.5463
# Epoch 3/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5706
# Epoch 00003: val_loss improved from 0.54634 to 0.52942, saving model to training/cp_autoencoder_03.ckpt
# 20/20 [==============================] - 3s 163ms/step - loss: 0.5679 - val_loss: 0.5294
# Epoch 4/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5589
# Epoch 00004: val_loss improved from 0.52942 to 0.52207, saving model to training/cp_autoencoder_04.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5583 - val_loss: 0.5221
# Epoch 5/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5496
# Epoch 00005: val_loss improved from 0.52207 to 0.51541, saving model to training/cp_autoencoder_05.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5507 - val_loss: 0.5154
# Epoch 6/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5497
# Epoch 00006: val_loss improved from 0.51541 to 0.50963, saving model to training/cp_autoencoder_06.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5480 - val_loss: 0.5096
# Epoch 7/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5432
# Epoch 00007: val_loss did not improve from 0.50963
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5394 - val_loss: 0.5098
# Epoch 8/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5387
# Epoch 00008: val_loss improved from 0.50963 to 0.50573, saving model to training/cp_autoencoder_08.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5377 - val_loss: 0.5057
# Epoch 9/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5378
# Epoch 00009: val_loss did not improve from 0.50573
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5365 - val_loss: 0.5075
# Epoch 10/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5355
# Epoch 00010: val_loss did not improve from 0.50573
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5362 - val_loss: 0.5080
# Epoch 11/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5359
# Epoch 00011: val_loss improved from 0.50573 to 0.50357, saving model to training/cp_autoencoder_11.ckpt
# 20/20 [==============================] - 1s 41ms/step - loss: 0.5346 - val_loss: 0.5036
# Epoch 12/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5355
# Epoch 00012: val_loss improved from 0.50357 to 0.50110, saving model to training/cp_autoencoder_12.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5339 - val_loss: 0.5011
# Epoch 13/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5326
# Epoch 00013: val_loss improved from 0.50110 to 0.50044, saving model to training/cp_autoencoder_13.ckpt
# 20/20 [==============================] - 1s 41ms/step - loss: 0.5319 - val_loss: 0.5004
# Epoch 14/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5317
# Epoch 00014: val_loss did not improve from 0.50044
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5331 - val_loss: 0.5015
# Epoch 15/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5306
# Epoch 00015: val_loss improved from 0.50044 to 0.49902, saving model to training/cp_autoencoder_15.ckpt
# 20/20 [==============================] - 1s 44ms/step - loss: 0.5305 - val_loss: 0.4990
# Epoch 16/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5296
# Epoch 00016: val_loss did not improve from 0.49902
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5308 - val_loss: 0.5009
# Epoch 17/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5313
# Epoch 00017: val_loss did not improve from 0.49902
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5309 - val_loss: 0.4999
# Epoch 18/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5269
# Epoch 00018: val_loss did not improve from 0.49902
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5299 - val_loss: 0.5001
# Epoch 19/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5314
# Epoch 00019: val_loss did not improve from 0.49902
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5311 - val_loss: 0.5015
# Epoch 20/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5287
# Epoch 00020: val_loss improved from 0.49902 to 0.49739, saving model to training/cp_autoencoder_20.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5299 - val_loss: 0.4974
# Epoch 21/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5290
# Epoch 00021: val_loss improved from 0.49739 to 0.49736, saving model to training/cp_autoencoder_21.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5287 - val_loss: 0.4974
# Epoch 22/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5287
# Epoch 00022: val_loss improved from 0.49736 to 0.49728, saving model to training/cp_autoencoder_22.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5280 - val_loss: 0.4973
# Epoch 23/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5279
# Epoch 00023: val_loss did not improve from 0.49728
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5283 - val_loss: 0.4976
# Epoch 24/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5307
# Epoch 00024: val_loss did not improve from 0.49728
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5295 - val_loss: 0.5013
# Epoch 25/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5292
# Epoch 00025: val_loss improved from 0.49728 to 0.49713, saving model to training/cp_autoencoder_25.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5293 - val_loss: 0.4971
# Epoch 26/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5280
# Epoch 00026: val_loss did not improve from 0.49713
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5283 - val_loss: 0.4979
# Epoch 27/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5304
# Epoch 00027: val_loss improved from 0.49713 to 0.49659, saving model to training/cp_autoencoder_27.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5275 - val_loss: 0.4966
# Epoch 28/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5295
# Epoch 00028: val_loss improved from 0.49659 to 0.49597, saving model to training/cp_autoencoder_28.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5273 - val_loss: 0.4960
# Epoch 29/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5282
# Epoch 00029: val_loss improved from 0.49597 to 0.49566, saving model to training/cp_autoencoder_29.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5268 - val_loss: 0.4957
# Epoch 30/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5275
# Epoch 00030: val_loss improved from 0.49566 to 0.49557, saving model to training/cp_autoencoder_30.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5266 - val_loss: 0.4956
# Epoch 31/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5296
# Epoch 00031: val_loss improved from 0.49557 to 0.49500, saving model to training/cp_autoencoder_31.ckpt
# 20/20 [==============================] - 1s 44ms/step - loss: 0.5266 - val_loss: 0.4950
# Epoch 32/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5268
# Epoch 00032: val_loss did not improve from 0.49500
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5267 - val_loss: 0.4964
# Epoch 33/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5274
# Epoch 00033: val_loss improved from 0.49500 to 0.49487, saving model to training/cp_autoencoder_33.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5263 - val_loss: 0.4949
# Epoch 34/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5266
# Epoch 00034: val_loss did not improve from 0.49487
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5262 - val_loss: 0.4949
# Epoch 35/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5252
# Epoch 00035: val_loss improved from 0.49487 to 0.49456, saving model to training/cp_autoencoder_35.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5260 - val_loss: 0.4946
# Epoch 36/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5288
# Epoch 00036: val_loss improved from 0.49456 to 0.49450, saving model to training/cp_autoencoder_36.ckpt
# 20/20 [==============================] - 1s 60ms/step - loss: 0.5268 - val_loss: 0.4945
# Epoch 37/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5250
# Epoch 00037: val_loss improved from 0.49450 to 0.49431, saving model to training/cp_autoencoder_37.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5256 - val_loss: 0.4943
# Epoch 38/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5280
# Epoch 00038: val_loss did not improve from 0.49431
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5271 - val_loss: 0.4946
# Epoch 39/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5237
# Epoch 00039: val_loss did not improve from 0.49431
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5255 - val_loss: 0.4945
# Epoch 40/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5242
# Epoch 00040: val_loss did not improve from 0.49431
# 20/20 [==============================] - 1s 69ms/step - loss: 0.5253 - val_loss: 0.4951
# Epoch 41/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5263
# Epoch 00041: val_loss improved from 0.49431 to 0.49404, saving model to training/cp_autoencoder_41.ckpt
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5259 - val_loss: 0.4940
# Epoch 42/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5244
# Epoch 00042: val_loss did not improve from 0.49404
# 20/20 [==============================] - 1s 41ms/step - loss: 0.5252 - val_loss: 0.4945
# Epoch 43/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5257
# Epoch 00043: val_loss did not improve from 0.49404
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5257 - val_loss: 0.4942
# Epoch 44/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5247
# Epoch 00044: val_loss improved from 0.49404 to 0.49402, saving model to training/cp_autoencoder_44.ckpt
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5254 - val_loss: 0.4940
# Epoch 45/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5256
# Epoch 00045: val_loss improved from 0.49402 to 0.49358, saving model to training/cp_autoencoder_45.ckpt
# 20/20 [==============================] - 1s 42ms/step - loss: 0.5252 - val_loss: 0.4936
# Epoch 46/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5238
# Epoch 00046: val_loss did not improve from 0.49358
# 20/20 [==============================] - 1s 40ms/step - loss: 0.5251 - val_loss: 0.4937
# Epoch 47/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5262
# Epoch 00047: val_loss did not improve from 0.49358
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5254 - val_loss: 0.4953
# Epoch 48/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5265
# Epoch 00048: val_loss did not improve from 0.49358
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5249 - val_loss: 0.4947
# Epoch 49/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5242
# Epoch 00049: val_loss did not improve from 0.49358
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5256 - val_loss: 0.4941
# Epoch 50/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5258
# Epoch 00050: val_loss did not improve from 0.49358
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5249 - val_loss: 0.4939
# Epoch 51/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5242
# Epoch 00051: val_loss improved from 0.49358 to 0.49305, saving model to training/cp_autoencoder_51.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5245 - val_loss: 0.4930
# Epoch 52/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00052: val_loss did not improve from 0.49305
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5243 - val_loss: 0.4938
# Epoch 53/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5242
# Epoch 00053: val_loss did not improve from 0.49305
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5255 - val_loss: 0.4935
# Epoch 54/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5245
# Epoch 00054: val_loss improved from 0.49305 to 0.49302, saving model to training/cp_autoencoder_54.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5251 - val_loss: 0.4930
# Epoch 55/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5271
# Epoch 00055: val_loss did not improve from 0.49302
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5249 - val_loss: 0.4932
# Epoch 56/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5253
# Epoch 00056: val_loss improved from 0.49302 to 0.49288, saving model to training/cp_autoencoder_56.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5249 - val_loss: 0.4929
# Epoch 57/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5263
# Epoch 00057: val_loss did not improve from 0.49288
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5248 - val_loss: 0.4932
# Epoch 58/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5219
# Epoch 00058: val_loss did not improve from 0.49288
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5245 - val_loss: 0.4930
# Epoch 59/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5274
# Epoch 00059: val_loss did not improve from 0.49288
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5257 - val_loss: 0.4931
# Epoch 60/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5246
# Epoch 00060: val_loss improved from 0.49288 to 0.49264, saving model to training/cp_autoencoder_60.ckpt
# 20/20 [==============================] - 1s 39ms/step - loss: 0.5243 - val_loss: 0.4926
# Epoch 61/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5246
# Epoch 00061: val_loss did not improve from 0.49264
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5244 - val_loss: 0.4934
# Epoch 62/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5250
# Epoch 00062: val_loss did not improve from 0.49264
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5246 - val_loss: 0.4930
# Epoch 63/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00063: val_loss improved from 0.49264 to 0.49243, saving model to training/cp_autoencoder_63.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5238 - val_loss: 0.4924
# Epoch 64/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5226
# Epoch 00064: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5239 - val_loss: 0.4930
# Epoch 65/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5251
# Epoch 00065: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5242 - val_loss: 0.4925
# Epoch 66/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5220
# Epoch 00066: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5239 - val_loss: 0.4925
# Epoch 67/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5235
# Epoch 00067: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5240 - val_loss: 0.4936
# Epoch 68/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5271
# Epoch 00068: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5242 - val_loss: 0.4934
# Epoch 69/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5240
# Epoch 00069: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5243 - val_loss: 0.4938
# Epoch 70/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5238
# Epoch 00070: val_loss improved from 0.49243 to 0.49243, saving model to training/cp_autoencoder_70.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5246 - val_loss: 0.4924
# Epoch 71/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5286
# Epoch 00071: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5239 - val_loss: 0.4925
# Epoch 72/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5240
# Epoch 00072: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5242 - val_loss: 0.4927
# Epoch 73/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5238
# Epoch 00073: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5241 - val_loss: 0.4925
# Epoch 74/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00074: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5233 - val_loss: 0.4927
# Epoch 75/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5228
# Epoch 00075: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5242 - val_loss: 0.4927
# Epoch 76/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5256
# Epoch 00076: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5242 - val_loss: 0.4927
# Epoch 77/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5233
# Epoch 00077: val_loss did not improve from 0.49243
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5236 - val_loss: 0.4928
# Epoch 78/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5219
# Epoch 00078: val_loss improved from 0.49243 to 0.49228, saving model to training/cp_autoencoder_78.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5236 - val_loss: 0.4923
# Epoch 79/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5230
# Epoch 00079: val_loss improved from 0.49228 to 0.49194, saving model to training/cp_autoencoder_79.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5238 - val_loss: 0.4919
# Epoch 80/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00080: val_loss did not improve from 0.49194
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5236 - val_loss: 0.4929
# Epoch 81/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00081: val_loss did not improve from 0.49194
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5236 - val_loss: 0.4920
# Epoch 82/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5231
# Epoch 00082: val_loss did not improve from 0.49194
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5232 - val_loss: 0.4926
# Epoch 83/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5251
# Epoch 00083: val_loss did not improve from 0.49194
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5240 - val_loss: 0.4939
# Epoch 84/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5251
# Epoch 00084: val_loss did not improve from 0.49194
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5239 - val_loss: 0.4926
# Epoch 85/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5232
# Epoch 00085: val_loss improved from 0.49194 to 0.49190, saving model to training/cp_autoencoder_85.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5234 - val_loss: 0.4919
# Epoch 86/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5232
# Epoch 00086: val_loss improved from 0.49190 to 0.49153, saving model to training/cp_autoencoder_86.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5231 - val_loss: 0.4915
# Epoch 87/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5248
# Epoch 00087: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5232 - val_loss: 0.4916
# Epoch 88/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00088: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5230 - val_loss: 0.4918
# Epoch 89/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00089: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5237 - val_loss: 0.4918
# Epoch 90/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5246
# Epoch 00090: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5235 - val_loss: 0.4924
# Epoch 91/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5249
# Epoch 00091: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5242 - val_loss: 0.4922
# Epoch 92/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5260
# Epoch 00092: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5238 - val_loss: 0.4918
# Epoch 93/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5233
# Epoch 00093: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5231 - val_loss: 0.4915
# Epoch 94/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5244
# Epoch 00094: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5230 - val_loss: 0.4923
# Epoch 95/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5227
# Epoch 00095: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5235 - val_loss: 0.4922
# Epoch 96/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5255
# Epoch 00096: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5233 - val_loss: 0.4931
# Epoch 97/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5239
# Epoch 00097: val_loss did not improve from 0.49153
# 20/20 [==============================] - 1s 37ms/step - loss: 0.5239 - val_loss: 0.4918
# Epoch 98/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5223
# Epoch 00098: val_loss improved from 0.49153 to 0.49139, saving model to training/cp_autoencoder_98.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5236 - val_loss: 0.4914
# Epoch 99/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5238
# Epoch 00099: val_loss did not improve from 0.49139
# 20/20 [==============================] - 1s 36ms/step - loss: 0.5235 - val_loss: 0.4916
# Epoch 100/100
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5234
# Epoch 00100: val_loss improved from 0.49139 to 0.49118, saving model to training/cp_autoencoder_100.ckpt
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5229 - val_loss: 0.4912

# %% [markdown]
# Nous pouvons observer sur le graphique précédent une diminution de la loss au fil des epochs pour le jeu d'entrainement et aussi pour le jeu de test, ce qui montre que notre modèle apprend des choses.

# %% [markdown]
# Le code qui suit va utiliser notre modèle entrainé pour enlever le bruit d'images bruitées passées en paramètres.

# %%
decoded_imgs = autoencoder.predict(tf.convert_to_tensor(noisy_test_set, dtype=tf.float32))

# %%
imgs_diff_clean_x_decoded = np.greater(np.absolute(np.subtract(clean_test_set.astype(float),decoded_imgs.astype(float))),0.2)

# %% [markdown]
# La première ligne correspond à la sortie du modèle, la seconde ligne correspond à l'image bruitée passée en entrée et la troisième ligne correspond à l'image original et la dernière ligne correspond à la différence supérieur à 0.2 entre l'image original et l'image en sortie du modèle.

# %%
display_image(decoded_imgs, 6)
display_image(noisy_test_set, 6)
display_image(clean_test_set, 6)
display_image(imgs_diff_clean_x_decoded, 6)

# %% [markdown]
# Dans la dernière ligne, un pixel noir signifie qu'il n'y a pas de différence entre le pixel original et le pixel en sortie du modèle neuronal. Un pixel "allumé" signifie qu'il y a une différence de valeur de plus de 0,2. On peut donc voir que notre modèle est très performant et que les différences, très légères, se situent sur les contours des objets.

# %%
# !tensorboard dev upload --logdir ./logs \
  --name "Livrable 2 : Projet Datascience - Leyenda." \
  --description "Modèle autoencodeur de débruitage." \
  --one_shot
# Out:
# New experiment created. View your TensorBoard at: https://tensorboard.dev/experiment/BNDVnxmnRomRKp0YlNjkgw/
#
# [2022-01-05T10:05:19] Started scanning logdir.
# [2022-01-05T10:05:22] Total uploaded: 300 scalars, 1400 tensors (1006.3 kB), 1 binary objects (63.3 kB)
# [2022-01-05T10:05:22] Done scanning logdir.
#
#
# Done. View your TensorBoard at https://tensorboard.dev/experiment/BNDVnxmnRomRKp0YlNjkgw/

# %% [markdown]
# ## Schématisation de notre modèle et explication des couches

# %%
tf.keras.utils.plot_model(
autoencoder, to_file='model_auto_encodeur.png', show_shapes=True, show_dtype=False,
show_layer_names=True, expand_nested=True, dpi=96
)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# Voici la schématisation de notre auto encodeur :
# ![model_auto_encodeur](images/model_auto_encodeur.png)
#
# - Une layers Input
#     - Plusieurs couches en fonction du paramètre filters (encodeur) :
#         - Une layers Conv2D
#         - Une layers MaxPooling2D
# > L'encodeur prend les données de grande dimension et les compressent vers une plus petite dimension.
#
#     - Plusieurs couches en fonction du paramètre filters (décodeur) :
#         - Une layers Conv2D
#         - Une layers UpSampling2D
#         - Une layers Conv2D
# >Le décodeur qui prend les données en petite dimension et les rétroprojette vers la plus grande dimension.
#
# Voici une autre schématisation de notre autoencodeur :
# ![Autoencodeur](images/Autoencodeur.png)

# %% [markdown]
# ## Analyse des résultats

# %% [markdown]
# Dans un premier temps, nous avons entrainer notre modèle avec un dataset de taille 100 et 100 epochs. Les courbes de loss pour l'entrainement et la test sont en dents de scies avec un minimum à 0.279 pour la validation.
#
# ![Courbes de loss pour 100 images et 100 epochs](images/loss_curves_autoencoder_100images_100epochs.png)
#
# Dans un second temps, nous avons entrainer notre modèle avec un dataset de taille 200 et 100 epochs. Les courbes de loss pour l'entrainement et la test sont beaucoup plus lisses avec un minimum à 0.2020 pour la validation.
#
# ![Courbes de loss pour 100 images et 100 epochs](images/loss_curves_autoencoder_200images_100epochs.png)
#
# Enfin nous avons décider de réduire le nombre d'epochs à 40 ainsi que d'augmenter la taille du dataset à 400.
# ![Courbes de loss pour 100 images et 100 epochs](images/autoencoder_40epochs_400images.png)
# Ce dernier modèle nous présente les résultats les plus probants avec la courbe de perte la plus lisse.

# %% [markdown]
# ## Analyse biais-variance
#
# Grâce aux résultats obtenus ci-dessus on peut déduire les paramètres qui optimizent le mieux le compromis biais-variance.
#
# Dans un premier temps, pour des questions de rapidité, nous avons entrainé notre modèle avec seulement 100 images. Le biais était fort car le dataset n'était pas assez varié.
# Le problème qui en découle est que ce modèle peut surévaluer certaine feature d'une image et donc mal réagir sur des photos qu'il ne connait pas.
# De plus nous avions réalisé notre entrainement sur 100 epochs. On constate donc de l'overfitting autour de la 50 ème epoch avec l'oscillement de la courbe de loss.
# En effet, le modèle ne progresse plus mais continu de faire évoluer et donc apprend par coeur notre dataset.
#
# Ainsi le meilleur moyen d'obtenir un bon compris biais variance est de diminuer les epochs (à 40 pour notre cas) et augmenter le nombre d'images d'entrainement (passage de 100 à 400).
# Dans ce cas présent, nous avons décidé de ne pas utiliser de technique de régularisation car l'apprentissage se fait de manière non supervisé.
